# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
last_fact = 1
cache = {last_fact: 1}

def fact(N):
    global last_fact, cache
    if N < 2:
        return 1
    if N in cache:
        return cache[N]
    result = cache[last_fact]
    for i in range(last_fact+1, N+1):
        result = result * i
        cache[i] = result
    return cache[N]

def f(N):
    result = fact(N)
    nb0s = 0
    while result % 10 == 0:
        result = result // 10
        nb0s += 1
    return nb0s

# %%
x2 = [x*x for x in range(100)]
plt.plot(x2)
plt.ylabel('x*x')
plt.show()

# %%
fx = [f(x) for x in range(10000)]
plt.plot(fx)
plt.ylabel('trailing_0s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-646817286dc9> in <module>()
# ----> 1 fx = [f(x) for x in range(10000)]
#       2 plt.plot(fx)
#       3 plt.ylabel('trailing_0s')
#       4 plt.show()
#
# <ipython-input-23-646817286dc9> in <listcomp>(.0)
# ----> 1 fx = [f(x) for x in range(10000)]
#       2 plt.plot(fx)
#       3 plt.ylabel('trailing_0s')
#       4 plt.show()
#
# <ipython-input-21-8998d9f02550> in f(N)
#      14
#      15 def f(N):
# ---> 16     result = fact(N)
#      17     nb0s = 0
#      18     while result % 10 == 0:
#
# <ipython-input-21-8998d9f02550> in fact(N)
#      10     result = cache[last_fact]
#      11     for i in range(last_fact+1, N+1):
# ---> 12         cache[i] = result * i
#      13     return cache[N]
#      14
#
# KeyboardInterrupt:

# %%
fact(10)
# Out:
# 10
